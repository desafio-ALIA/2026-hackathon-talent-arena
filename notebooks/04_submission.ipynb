# %% [markdown]
# # Submission de los resultados
# Este notebook está pensado para el final del reto. Se os compartirá un dataset para realizar predicciones con vuestro modelo.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
from datasets import Dataset
import pandas as pd
from dotenv import load_dotenv
from sklearn.metrics import classification_report

load_dotenv()

# Añadir src al path
sys.path.append(os.path.abspath(os.path.join('../src')))

from model_utils import *
from data_utils import *
from prompts import ABS_SYSTEM_PROMPT, ABSOLUTE_PROMPT
from submission import Submission

# %% [markdown]
# Cargamos el modelo finetuneado

# %%
DATA_INPUT_FILENAME = os.getenv("DATA_INPUT_FILENAME", "../data/dataset_sample.json")
MODEL_NAME = os.getenv("MODEL_NAME", "prometheus-eval/prometheus-7b-v2.0")
MODEL_FT_PATH = os.getenv("MODEL_FT_PATH", "../output/prometheus_finetuned")

# %%
model, tokenizer = load_lora_model(MODEL_NAME, MODEL_FT_PATH)

# %% [markdown]
# ### ⚠️ Importante sobre el Prompt de Evaluación\nSi decides afinar o modificar el \ABSOLUTE_PROMPT\ original y se lo pasas a tu ejecución, asegúrate de mantener como mínimo obligatoriamente los placeholders o variables \{question}\, \{answer}\ y \{proposed_answer}\ en el texto del prompt. Son necesarios para poder inyectar dinámicamente la pregunta del usuario, la respuesta y el ground-truth a juzgar para cada caso.

# %% [markdown]
# ### ⚠️ Importante sobre el Prompt de Evaluación
# Si decides afinar o modificar el `ABSOLUTE_PROMPT` original y se lo pasas a tu ejecución, asegúrate de mantener como mínimo obligatoriamente los placeholders o variables `{question}`, `{answer}` y `{proposed_answer}` en el texto del prompt. Son necesarios para poder inyectar dinámicamente la pregunta del usuario, la respuesta y el ground-truth a juzgar para cada caso.

# %%
input_file = "ruta_al_fichero_compartido.json" # Fichero que se os compartirá para evaluar el resultado
output_file = "submission.json" # Fichero resultante con las predicciones
team_name = "tu_nombre_de_equipo" # Nombre de vuestro equipo

# 1. Se coge el fichero y se inicializa la clase Submission
submission = Submission(input_file)

# 2. Se hace predict (incluyendo test de robustez)
# 3. Se crea el fichero final y ese seria el resultante
df_submission = submission.generate_submission(
    model=model, 
    tokenizer=tokenizer, 
    system_prompt=ABS_SYSTEM_PROMPT, 
    absolute_prompt=ABSOLUTE_PROMPT, 
    team_name=team_name, 
    output_file=output_file
)

df_submission.head()
